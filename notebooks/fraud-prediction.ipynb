# %% [markdown]
# # Entorno Sandbox: Exploración del Dataset de Fraude Crediticio (EDA)
# Este _notebook_ actúa como tu entorno de investigación para probar nuevos algoritmos (como PCA, Neural Networks) de forma segura antes de migrar el código a la carpeta `/src/` para ser llamado en el pipeline MLOps.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# 1. Análisis de Correlación y Carga
try:
    df = pd.read_csv('../creditcard.csv')
    print("Dimensiones del Ténsor:", df.shape)
    print("\nBalance de Clases (Fraude = 1):")
    print(df['Class'].value_counts(normalize=True) * 100)
except Exception as e:
    print("El dataset aún no ha sido descargado al entorno de experimentación.", e)
